# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load all dataset
student_data = pd.read_csv('/content/UCI-student-mat.csv', sep=';')
assessments = pd.read_csv('/content/assessments.csv')
courses = pd.read_csv('/content/courses.csv')
studentAssessment = pd.read_csv('/content/studentAssessment.csv')
studentInfo = pd.read_csv('/content/studentInfo.csv')
studentRegistration = pd.read_csv('/content/studentRegistration.csv')
studentVle = pd.read_csv('/content/studentVle.csv')
vle = pd.read_csv('/content/vle.csv')

# %%
print("UCI Student Dataset: Student Mat Data\n")
student_data.head()
# Out:
# UCI Student Dataset: Student Mat Data
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
print("OULA Dataset: Assessment\n")
assessments.head()
# Out:
# OULA Dataset: Assessment
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0

# %%
assessments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        206 non-null    object
#  1   code_presentation  206 non-null    object
#  2   id_assessment      206 non-null    int64
#  3   assessment_type    206 non-null    object
#  4   date               195 non-null    float64
#  5   weight             206 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.8+ KB

# %%
print("OULA Dataset: Courses\n")
courses.head()
# Out:
# OULA Dataset: Courses
#   code_module code_presentation  module_presentation_length
# 0         AAA             2013J                         268
# 1         AAA             2014J                         269
# 2         BBB             2013J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240

# %%
courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   code_module                 22 non-null     object
#  1   code_presentation           22 non-null     object
#  2   module_presentation_length  22 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 656.0+ bytes

# %%
print("OULA Dataset: Student Assessment\n")
studentAssessment.head()
# Out:
# OULA Dataset: Student Assessment
#    id_assessment  id_student  date_submitted  is_banked  score
# 0           1752       11391              18          0   78.0
# 1           1752       28400              22          0   70.0
# 2           1752       31604              17          0   72.0
# 3           1752       32885              26          0   69.0
# 4           1752       38053              19          0   79.0

# %%
studentAssessment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173912 entries, 0 to 173911
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_assessment   173912 non-null  int64
#  1   id_student      173912 non-null  int64
#  2   date_submitted  173912 non-null  int64
#  3   is_banked       173912 non-null  int64
#  4   score           173739 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 6.6 MB

# %%
print("OULA Dataset: StudentInfo\n")
studentInfo.head()
# Out:
# OULA Dataset: StudentInfo
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# ...

# %%
studentInfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           32593 non-null  object
#  1   code_presentation     32593 non-null  object
#  2   id_student            32593 non-null  int64
#  3   gender                32593 non-null  object
#  4   region                32593 non-null  object
#  5   highest_education     32593 non-null  object
#  6   imd_band              31482 non-null  object
#  7   age_band              32593 non-null  object
#  8   num_of_prev_attempts  32593 non-null  int64
#  9   studied_credits       32593 non-null  int64
#  10  disability            32593 non-null  object
#  11  final_result          32593 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB

# %%
print("OULA Dataset: StudentRegisteration\n")
studentRegistration.head()
# Out:
# OULA Dataset: StudentRegisteration
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN

# %%
studentRegistration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   code_module          32593 non-null  object
#  1   code_presentation    32593 non-null  object
#  2   id_student           32593 non-null  int64
#  3   date_registration    32548 non-null  float64
#  4   date_unregistration  10072 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.2+ MB

# %%
print("OULA Dataset: StudentVle\n")
studentVle.head()
# Out:
# OULA Dataset: StudentVle
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1

# %%
studentVle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10655280 entries, 0 to 10655279
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   code_module        object
#  1   code_presentation  object
#  2   id_student         int64
#  3   id_site            int64
#  4   date               int64
#  5   sum_click          int64
# dtypes: int64(4), object(2)
# memory usage: 487.8+ MB

# %%
print("OULA Dataset: Vle\n")
vle.head()
# Out:
# OULA Dataset: Vle
#    id_site code_module code_presentation activity_type  week_from  week_to
# 0   546943         AAA             2013J      resource        NaN      NaN
# 1   546712         AAA             2013J     oucontent        NaN      NaN
# 2   546998         AAA             2013J      resource        NaN      NaN
# 3   546888         AAA             2013J           url        NaN      NaN
# 4   547035         AAA             2013J      resource        NaN      NaN

# %%
vle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6364 entries, 0 to 6363
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_site            6364 non-null   int64
#  1   code_module        6364 non-null   object
#  2   code_presentation  6364 non-null   object
#  3   activity_type      6364 non-null   object
#  4   week_from          1121 non-null   float64
#  5   week_to            1121 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 298.4+ KB

# %%
dataframe_names = ['assessments', 'courses', 'studentAssessment', 'studentInfo', 'studentRegistration', 'studentVle', 'vle']
dataframes = [assessments, courses, studentAssessment, studentInfo, studentRegistration, studentVle, vle]

for name, df in zip(dataframe_names, dataframes):
    print(f"Missing values in {name} dataset:")
    print(df.isnull().sum(), "\n")
    print(df.shape, "\n")
# Out:
# Missing values in assessments dataset:
# code_module           0
# code_presentation     0
# id_assessment         0
# assessment_type       0
# date                 11
# weight                0
# dtype: int64
#
# (206, 6)
#
# Missing values in courses dataset:
# code_module                   0
# code_presentation             0
# module_presentation_length    0
# dtype: int64
#
# (22, 3)
#
# Missing values in studentAssessment dataset:
# id_assessment       0
# id_student          0
# date_submitted      0
# is_banked           0
# score             173
# dtype: int64
#
# (173912, 5)
#
# Missing values in studentInfo dataset:
# code_module                0
# code_presentation          0
# id_student                 0
# gender                     0
# region                     0
# highest_education          0
# imd_band                1111
# age_band                   0
# num_of_prev_attempts       0
# studied_credits            0
# disability                 0
# ...

# %%
# Impute missing imd_band with mode
mode_value = studentInfo['imd_band'].mode()[0]
studentInfo['imd_band'].fillna(mode_value, inplace=True)

# %%
# Impute missing scores with 0 if it indicates no attempt
studentAssessment['score'].fillna(0, inplace=True)

# %%
# Replace missing values with median date
median_date = assessments['date'].median()
assessments['date'].fillna(median_date, inplace=True)

# %%
# Fill missing values in date_unregistration with a placeholder (e.g., 0 or a specific value)
studentRegistration['date_unregistration'].fillna(-1, inplace=True)

# %%
# Drop week_from and week_to columns
vle.drop(columns=['week_from', 'week_to'], inplace=True)

# %%
dataframe_names = ['assessments', 'courses', 'studentAssessment', 'studentInfo', 'studentRegistration', 'studentVle', 'vle']
dataframes = [assessments, courses, studentAssessment, studentInfo, studentRegistration, studentVle, vle]

for name, df in zip(dataframe_names, dataframes):
    print(f"Missing values in {name} dataset:")
    print(df.isnull().sum(), "\n")
    print(df.shape, "\n")
# Out:
# Missing values in assessments dataset:
# code_module          0
# code_presentation    0
# id_assessment        0
# assessment_type      0
# date                 0
# weight               0
# dtype: int64
#
# (206, 6)
#
# Missing values in courses dataset:
# code_module                   0
# code_presentation             0
# module_presentation_length    0
# dtype: int64
#
# (22, 3)
#
# Missing values in studentAssessment dataset:
# id_assessment     0
# id_student        0
# date_submitted    0
# is_banked         0
# score             0
# dtype: int64
#
# (173912, 5)
#
# Missing values in studentInfo dataset:
# code_module             0
# code_presentation       0
# id_student              0
# gender                  0
# region                  0
# highest_education       0
# imd_band                0
# age_band                0
# num_of_prev_attempts    0
# studied_credits         0
# disability              0
# final_result            0
# dtype: int64
#
# (32593, 12)
#
# ...

# %%
# Rename overlapping columns
vle.rename(columns={
    'code_module': 'code_module_vle',
    'code_presentation': 'code_presentation_vle'
}, inplace=True)


# Merge datasets
# 1. Merge studentInfo with studentRegistration
combined_df = pd.merge(studentInfo, studentRegistration, on='id_student', how='left')

# Dropping columns with suffixes and keeping only one set of 'code_module' and 'code_presentation'
combined_df = combined_df.loc[:, ~combined_df.columns.str.contains('_y')]

# Rename columns if necessary
combined_df.rename(columns={'code_module_x': 'code_module', 'code_presentation_x': 'code_presentation'}, inplace=True)

print("Cleaned Combined DataFrame:")
combined_df.head()
# Out:
# Cleaned Combined DataFrame:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result  date_registration  \
# ...

# %%
# 2. Merge with studentAssessment
combined_df = pd.merge(combined_df, studentAssessment, on='id_student', how='left')
combined_df.head()
# Out:
#   code_module code_presentation  id_student gender               region  \
# 0         AAA             2013J       11391      M  East Anglian Region
# 1         AAA             2013J       11391      M  East Anglian Region
# 2         AAA             2013J       11391      M  East Anglian Region
# 3         AAA             2013J       11391      M  East Anglian Region
# 4         AAA             2013J       11391      M  East Anglian Region
#
#   highest_education imd_band age_band  num_of_prev_attempts  studied_credits  \
# 0  HE Qualification  90-100%     55<=                     0              240
# 1  HE Qualification  90-100%     55<=                     0              240
# 2  HE Qualification  90-100%     55<=                     0              240
# 3  HE Qualification  90-100%     55<=                     0              240
# 4  HE Qualification  90-100%     55<=                     0              240
#
#   disability final_result  date_registration  date_unregistration  \
# ...

# %%
# 3. Merge with assessments
combined_df = pd.merge(combined_df, assessments, on=['code_module', 'code_presentation'], how='left')
combined_df.head()

# %%
# 4. Merge with studentVle
#combined_df = pd.merge(combined_df, studentVle, on=['code_module', 'code_presentation', 'id_student'], how='left')
student_data = pd.merge(student_data, studentVle, left_on=['id_student', 'code_module', 'code_presentation'], right_on=['id_student', 'code_module_vle', 'code_presentation_vle'], how='left')

# 5. Merge with vle
combined_df = pd.merge(combined_df, vle, left_on='id_site', right_on='id_site', how='left')

# Review the combined DataFrame
print("Combined Data Info:")
print(combined_df.info())

# %%
combined_df.head()
# Out:
#   code_module_x code_presentation_x  id_student gender                region  \
# 0           AAA               2013J       11391      M   East Anglian Region
# 1           AAA               2013J       28400      F              Scotland
# 2           AAA               2013J       30268      F  North Western Region
# 3           AAA               2013J       31604      F     South East Region
# 4           AAA               2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result code_module_y code_presentation_y  \
# ...

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279801 entries, 0 to 279800
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   code_module_x         279801 non-null  object
#  1   code_presentation_x   279801 non-null  object
#  2   id_student            279801 non-null  int64
#  3   gender                279801 non-null  object
#  4   region                279801 non-null  object
#  5   highest_education     279801 non-null  object
#  6   imd_band              279801 non-null  object
#  7   age_band              279801 non-null  object
#  8   num_of_prev_attempts  279801 non-null  int64
#  9   studied_credits       279801 non-null  int64
#  10  disability            279801 non-null  object
#  11  final_result          279801 non-null  object
#  12  id_assessment         279801 non-null  int64
#  13  date_submitted        279801 non-null  int64
# ...

# %%
student_data.shape
# Out:
# (279801, 25)

# %%
student_vle.head()
# Out:
#   code_module_x code_presentation_x  id_student  id_site  date  sum_click  \
# 0           AAA               2013J       28400   546652   -10          4
# 1           AAA               2013J       28400   546652   -10          1
# 2           AAA               2013J       28400   546652   -10          1
# 3           AAA               2013J       28400   546652   -10          8
# 4           AAA               2013J       30268   546652   -10          3
#
#   code_module_y code_presentation_y activity_type
# 0           AAA               2013J       forumng
# 1           AAA               2013J       forumng
# 2           AAA               2013J       forumng
# 3           AAA               2013J       forumng
# 4           AAA               2013J       forumng

# %%
student_vle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10655280 entries, 0 to 10655279
# Data columns (total 9 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   code_module_x        object
#  1   code_presentation_x  object
#  2   id_student           int64
#  3   id_site              int64
#  4   date                 int64
#  5   sum_click            int64
#  6   code_module_y        object
#  7   code_presentation_y  object
#  8   activity_type        object
# dtypes: int64(4), object(5)
# memory usage: 731.6+ MB

# %%
student_vle.shape
# Out:
# (10655280, 9)

# %%
student
